# %%
# !pip install -q opensearch-py

# %%
# !pip install sentence-transformers
# Out:
# Collecting sentence-transformers
#   Downloading sentence_transformers-3.0.1-py3-none-any.whl.metadata (10 kB)
# Collecting transformers<5.0.0,>=4.34.0 (from sentence-transformers)
#   Downloading transformers-4.44.2-py3-none-any.whl.metadata (43 kB)
# Requirement already satisfied: tqdm in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.10/site-packages (from sentence-transformers) (4.66.5)
# Collecting torch>=1.11.0 (from sentence-transformers)
#   Downloading torch-2.4.0-cp310-cp310-manylinux1_x86_64.whl.metadata (26 kB)
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.10/site-packages (from sentence-transformers) (1.23.5)
# Collecting scikit-learn (from sentence-transformers)
#   Downloading scikit_learn-1.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting scipy (from sentence-transformers)
#   Downloading scipy-1.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Collecting huggingface-hub>=0.15.1 (from sentence-transformers)
#   Downloading huggingface_hub-0.24.6-py3-none-any.whl.metadata (13 kB)
# Collecting Pillow (from sentence-transformers)
#   Downloading pillow-10.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.2 kB)
# Collecting filelock (from huggingface-hub>=0.15.1->sentence-transformers)
#   Downloading filelock-3.15.4-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2.32.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.12.2)
# Collecting sympy (from torch>=1.11.0->sentence-transformers)
#   Downloading sympy-1.13.2-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (2.4)
# Requirement already satisfied: jinja2 in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==3.0.0 (from torch>=1.11.0->sentence-transformers)
#   Downloading triton-3.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.3 kB)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_nvjitlink_cu12-12.6.68-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting regex!=2019.12.17 (from transformers<5.0.0,>=4.34.0->sentence-transformers)
#   Downloading regex-2024.7.24-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
# Collecting safetensors>=0.4.1 (from transformers<5.0.0,>=4.34.0->sentence-transformers)
#   Downloading safetensors-0.4.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting tokenizers<0.20,>=0.19 (from transformers<5.0.0,>=4.34.0->sentence-transformers)
#   Downloading tokenizers-0.19.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting joblib>=1.2.0 (from scikit-learn->sentence-transformers)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->sentence-transformers)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.10/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: decorator>=4.3.0 in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.10/site-packages (from networkx->torch>=1.11.0->sentence-transformers) (5.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.10/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.10/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.10/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.10/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2024.7.4)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->torch>=1.11.0->sentence-transformers)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading sentence_transformers-3.0.1-py3-none-any.whl (227 kB)
# Downloading huggingface_hub-0.24.6-py3-none-any.whl (417 kB)
# Downloading torch-2.4.0-cp310-cp310-manylinux1_x86_64.whl (797.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.2/797.2 MB 42.2 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 85.2 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 145.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 145.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 58.3 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 49.9 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 47.9 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 35.4 MB/s eta 0:00:00:00:01
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 20.3 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 33.3 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 18.8 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Downloading triton-3.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (209.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 MB 27.8 MB/s eta 0:00:0000:0100:01
# Downloading transformers-4.44.2-py3-none-any.whl (9.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 31.1 MB/s eta 0:00:00:00:01
# Downloading pillow-10.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 16.5 MB/s eta 0:00:00ta 0:00:01
# Downloading scikit_learn-1.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 92.6 MB/s eta 0:00:00
# Downloading scipy-1.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (41.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 MB 105.6 MB/s eta 0:00:0000:01
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading regex-2024.7.24-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (776 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.5/776.5 kB 24.2 MB/s eta 0:00:00
# Downloading safetensors-0.4.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (435 kB)
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Downloading tokenizers-0.19.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 82.9 MB/s eta 0:00:00
# Downloading filelock-3.15.4-py3-none-any.whl (16 kB)
# Downloading sympy-1.13.2-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 78.7 MB/s eta 0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 6.2 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.6.68-py3-none-manylinux2014_x86_64.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 55.7 MB/s eta 0:00:00:00:01
# Installing collected packages: mpmath, threadpoolctl, sympy, scipy, safetensors, regex, Pillow, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, joblib, filelock, triton, scikit-learn, nvidia-cusparse-cu12, nvidia-cudnn-cu12, huggingface-hub, tokenizers, nvidia-cusolver-cu12, transformers, torch, sentence-transformers
# Successfully installed Pillow-10.4.0 filelock-3.15.4 huggingface-hub-0.24.6 joblib-1.4.2 mpmath-1.3.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.6.68 nvidia-nvtx-cu12-12.1.105 regex-2024.7.24 safetensors-0.4.4 scikit-learn-1.5.1 scipy-1.14.1 sentence-transformers-3.0.1 sympy-1.13.2 threadpoolctl-3.5.0 tokenizers-0.19.1 torch-2.4.0 transformers-4.44.2 triton-3.0.0

# %%
# !pip install graph-notebook --upgrade

# %%
# %reload_ext graph_notebook.magics

# %%
# %%sparql
# Out:
# UsageError: %%sparql is a cell magic, but the cell body is empty.

# %%
# !pwd
# Out:
# /home/ec2-user/SageMaker/Moviesearch

# %%
# !aws s3 ls s3://ekg-da-poc/index_load/
# Out:
# 2024-09-01 18:36:10          0
# 2024-09-02 21:38:08  772244589 xgnn_embeddings.csv
# 2024-09-02 21:36:08    6662412 xgnn_tt.txt
# 2024-09-02 21:34:12   28665937 xmovie.csv
# 2024-09-02 21:35:29    6662412 xmovie_tt.txt
# 2024-09-02 21:36:47 2825795390 xsentence_embeddings.csv
# 2024-09-02 21:35:52    6662412 xsentence_tt.txt

# %%
# !aws s3 cp s3://ekg-da-poc/index_load/xgnn_embeddings.csv .
# Out:
# download: s3://ekg-da-poc/index_load/xgnn_embeddings.csv to ./xgnn_embeddings.csv

# %%
# !aws s3 cp s3://ekg-da-poc/index_load/xgnn_tt.txt .
# Out:
# download: s3://ekg-da-poc/index_load/xgnn_tt.txt to ./xgnn_tt.txt

# %%
# !aws s3 cp s3://ekg-da-poc/index_load/xmovie.csv .
# Out:
# download: s3://ekg-da-poc/index_load/xmovie.csv to ./xmovie.csv

# %%
# !aws s3 cp s3://ekg-da-poc/index_load/xmovie_tt.txt .
# Out:
# download: s3://ekg-da-poc/index_load/xmovie_tt.txt to ./xmovie_tt.txt

# %%
# !aws s3 cp s3://ekg-da-poc/index_load/xsentence_embeddings.csv .
# Out:
# download: s3://ekg-da-poc/index_load/xsentence_embeddings.csv to ./xsentence_embeddings.csv

# %%
# !aws s3 cp s3://ekg-da-poc/index_load/xsentence_tt.txt .
# Out:
# download: s3://ekg-da-poc/index_load/xsentence_tt.txt to ./xsentence_tt.txt

# %%
# !ls -altr ./*
# Out:
# -rw-rw-r-- 1 ec2-user ec2-user   28665937 Sep  2 21:34 ./xmovie.csv
# -rw-rw-r-- 1 ec2-user ec2-user    6662412 Sep  2 21:35 ./xmovie_tt.txt
# -rw-rw-r-- 1 ec2-user ec2-user    6662412 Sep  2 21:35 ./xsentence_tt.txt
# -rw-rw-r-- 1 ec2-user ec2-user    6662412 Sep  2 21:36 ./xgnn_tt.txt
# -rw-rw-r-- 1 ec2-user ec2-user 2825795390 Sep  2 21:36 ./xsentence_embeddings.csv
# -rw-rw-r-- 1 ec2-user ec2-user  772244589 Sep  2 21:38 ./xgnn_embeddings.csv
# -rw-rw-r-- 1 ec2-user ec2-user      32458 Sep  3 14:42 ./MovieSearch-AOS-Indexing.ipynb
#
# ./NeptuneNbCopy:
# total 1468
# -rw-rw-r-- 1 ec2-user ec2-user  35508 Sep  3 14:32 AosMovieSearchSetup.ipynb
# -rw-rw-r-- 1 ec2-user ec2-user  24106 Sep  3 14:32 GnnWorking.ipynb
# -rw-rw-r-- 1 ec2-user ec2-user 134327 Sep  3 14:32 01-PopulateAndExploreNeptune.ipynb
# -rw-rw-r-- 1 ec2-user ec2-user 563183 Sep  3 14:32 02-PopulateOpenSearch.ipynb
# -rw-rw-r-- 1 ec2-user ec2-user 133036 Sep  3 14:32 00-PrepIMDBData.ipynb
# drwxrwxr-x 2 ec2-user ec2-user   4096 Sep  3 14:32 .
# -rw-rw-r-- 1 ec2-user ec2-user 596482 Sep  3 14:32 03-Search.ipynb
# drwxrwxr-x 5 ec2-user ec2-user   4096 Sep  3 14:45 ..
#
# ./SageMakerCopy:
# total 744
# -rw-rw-r-- 1 ec2-user ec2-user  21221 Sep  3 14:30 rgcn-gnn-embeddings-test.ipynb
# -rw-rw-r-- 1 ec2-user ec2-user  92155 Sep  3 14:30 MovieSearchFull.ipynb
# -rw-rw-r-- 1 ec2-user ec2-user 626886 Sep  3 14:30 03-Search(1).ipynb
# drwxrwxr-x 3 ec2-user ec2-user   4096 Sep  3 14:34 .
# drwxrwxr-x 2 ec2-user ec2-user   4096 Sep  3 14:34 .ipynb_checkpoints
# drwxrwxr-x 5 ec2-user ec2-user   4096 Sep  3 14:45 ..

# %%
# !diff xmovie_tt.txt xsentence_tt.txt | head -10

# %%
# !diff xmovie_tt.txt xgnn_tt.txt | head -10

# %%
# !diff xgnn_tt.txt xsentence_tt.txt | head -10

# %%
# !wc -l ./xmovie.csv ./xsentence_embeddings.csv ./xgnn_embeddings.csv
# Out:
#     600000 ./xmovie.csv
#     600000 ./xsentence_embeddings.csv
#     600000 ./xgnn_embeddings.csv
#    1800000 total

# %%
import boto3

REGION = boto3.Session().region_name

# Replace with your S3 bucket where you prepared the IMDB data for Neptune use
SOURCE_S3_PATH_NOSLASH=f"s3://ekg-da-poc"

# Replace with your Amazon OpenSearch Service domain endpoint
FTS_AOS_ENDPOINT="https://z9urozgne3v5p4ywe2fj.us-east-1.aoss.amazonaws.com"

VS_AOS_ENDPOINT="https://8kd01utb7q4h0s0lec3g.us-east-1.aoss.amazonaws.com"

# Replace with your IAM role for the GNN embedding pipeline.
SAGEMAKER_ROLE="arn:aws:iam::196856463470:role/SandboxServiceRole"

# %%
# !pip install -q opensearch-py

# %%
import boto3
from opensearchpy import OpenSearch, RequestsHttpConnection, AWSV4SignerAuth

service = 'aoss'
region = 'us-east-1'

credentials = boto3.Session().get_credentials()
auth = AWSV4SignerAuth(credentials, region, service)

fts_aos_client = OpenSearch(
    hosts = [{'host': FTS_AOS_ENDPOINT.split("//")[1], 'port': 443}],
    http_auth=auth,
    use_ssl = True,
    verify_certs = True,
    connection_class = RequestsHttpConnection,
    pool_maxsize=20,
)

# %%
import boto3
from opensearchpy import OpenSearch, RequestsHttpConnection, AWSV4SignerAuth

service = 'aoss'
region2 = 'us-east-1'

credentials = boto3.Session().get_credentials()
auth2 = AWSV4SignerAuth(credentials, region2, service)

vs_aos_client = OpenSearch(
    hosts = [{'host': VS_AOS_ENDPOINT.split("//")[1], 'port': 443}],
    http_auth=auth2,
    use_ssl = True,
    verify_certs = True,
    connection_class = RequestsHttpConnection,
    pool_maxsize=20,
)

# %%
vs_aos_client.indices.get_alias(index="*")
# Out:
# {'movie_sentence': {'aliases': {}},
#  'movie_gnn_4': {'aliases': {}},
#  'movie_2': {'aliases': {}},
#  'movie_gnn_3': {'aliases': {}},
#  'movie_gnn_2': {'aliases': {}},
#  'movie_4': {'aliases': {}},
#  'movie': {'aliases': {}},
#  'movie_3': {'aliases': {}},
#  'python-test-index': {'aliases': {}},
#  'books-index': {'aliases': {}},
#  'movie_sentence_4': {'aliases': {}},
#  '.opensearch_dashboards_1': {'aliases': {'.opensearch_dashboards': {}}},
#  'movie_sentence_3': {'aliases': {}},
#  'movie_gnn': {'aliases': {}},
#  'movie_sentence_2': {'aliases': {}}}

# %%
fts_aos_client.indices.get_alias(index="*")
# Out:
# {'movie_4': {'aliases': {}},
#  '.opensearch_dashboards_1': {'aliases': {'.opensearch_dashboards': {}}}}

# %%
# !pip install sentence-transformers

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

def get_embeddings(sentences):
    embeddings = model.encode(sentences)
    return embeddings

def get_str_embedding(embedding):
    return ';'.join([str(x) for x in embedding])

def parse_str_embedding(s):
    toks= s.split(";")
    return list(map(lambda x: float(x), toks))
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# /home/ec2-user/anaconda3/envs/JupyterSystemEnv/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
import csv

def csv_open(fname, headers):
    ff = []
    ff.append(open(fname, "w"))
    ff.append(csv.writer(ff[0]))
    csv_write(ff, headers)
    return ff

def csv_close(ff):
    ff[0].close()

def csv_write(ff, arr):
    ff[1].writerow("" if pd.isna(a) or a=='-' else a for a in arr)

# %%
#Amazon OpenSearch References on Semantic, Vector and Lexical Search
https://aws.amazon.com/blogs/big-data/try-semantic-search-with-the-amazon-opensearch-service-vector-engine/
https://opensearch.org/blog/semantic-science-benchmarks/
https://github.com/aws-samples/semantic-search-with-amazon-opensearch

# %%
movie_index_5 = {
    "settings": {
        "number_of_replicas": 1,
        "number_of_shards": 1,
        "analysis": {
          "analyzer": {
            "default": {
              "type": "standard",
              "stopwords": "_english_"
            }
          }
        }
    },
    "mappings" : {
    "properties" : {
      "title" : {
        "type" :  "text"
      },
      "id" : {
        "type" :  "text"
      }
    }
  }
}

# %%
movie_index_6 = {
    "settings": {
        "number_of_replicas": 1,
        "number_of_shards": 5,
        "index.knn": True,
        "analysis": {
          "analyzer": {
            "default": {
              "type": "standard",
              "stopwords": "_english_"
            }
          }
        }
    },
    "mappings": {
        "properties": {
            "title" : {
                "type" :  "text"
            },
            "id" : {
                "type" :  "text"
            },
            "sentence_embedding": {
                "type": "knn_vector",
                "dimension": 384,
                "method": {
                    "name": "hnsw",
                    "space_type": "cosinesimil",
                }
            },
            "gnn_embedding": {
                "type": "knn_vector",
                "dimension": 64,
                "method": {
                    "name": "hnsw",
                    "space_type": "cosinesimil",
                }
            }
        }
    }
}

# %%
movie_sentence_index_6 = {
    "settings": {
        "number_of_replicas": 1,
        "number_of_shards": 5,
        "index.knn": True,
        "analysis": {
          "analyzer": {
            "default": {
              "type": "standard",
              "stopwords": "_english_"
            }
          }
        }
    },
    "mappings": {
        "properties": {
            "title" : {
                "type" :  "text"
            },
            "id" : {
                "type" :  "text"
            },
            "sentence_embedding": {
                "type": "knn_vector",
                "dimension": 384,
                "method": {
                    "name": "hnsw",
                    "space_type": "cosinesimil",
                }
            },
            "gnn_embedding": {
                "type": "knn_vector",
                "dimension": 64,
                "method": {
                    "name": "hnsw",
                    "space_type": "cosinesimil",
                }
            }
        }
    }
}

# %%
movie_gnn_index_6 = {
    "settings": {
        "number_of_replicas": 1,
        "number_of_shards": 5,
        "index.knn": True,
        "analysis": {
          "analyzer": {
            "default": {
              "type": "standard",
              "stopwords": "_english_"
            }
          }
        }
    },
    "mappings": {
        "properties": {
            "title" : {
                "type" :  "text"
            },
            "id" : {
                "type" :  "text"
            },
            "sentence_embedding": {
                "type": "knn_vector",
                "dimension": 384,
                "method": {
                    "name": "hnsw",
                    "space_type": "cosinesimil",
                }
            },
            "gnn_embedding": {
                "type": "knn_vector",
                "dimension": 64,
                "method": {
                    "name": "hnsw",
                    "space_type": "cosinesimil",
                }
            }
        }
    }
}

# %%
vs_aos_client.indices.delete(index="movie_6")
vs_aos_client.indices.create(index="movie_6",body=movie_index_6)

vs_aos_client.indices.delete(index="movie_sentence_6")
vs_aos_client.indices.create(index="movie_sentence_6",body=movie_sentence_index_6)

vs_aos_client.indices.delete(index="movie_gnn_6")
vs_aos_client.indices.create(index="movie_gnn_6",body=movie_gnn_index_6)
# Out:
# {'acknowledged': True, 'shards_acknowledged': True, 'index': 'movie_gnn_6'}

# %%
vs_aos_client.indices.create(index="movie_7",body=movie_index_6)

vs_aos_client.indices.create(index="movie_sentence_7",body=movie_sentence_index_6)

vs_aos_client.indices.create(index="movie_gnn_7",body=movie_gnn_index_6)
# Out:
# {'acknowledged': True, 'shards_acknowledged': True, 'index': 'movie_gnn_7'}

# %%
vs_aos_client.indices.get(index="movie_7")
# Out:
# {'movie_7': {'aliases': {},
#   'mappings': {'properties': {'gnn_embedding': {'type': 'knn_vector',
#      'dimension': 64,
#      'method': {'engine': 'nmslib',
#       'space_type': 'cosinesimil',
#       'name': 'hnsw',
#       'parameters': {}}},
#     'id': {'type': 'text'},
#     'sentence_embedding': {'type': 'knn_vector',
#      'dimension': 384,
#      'method': {'engine': 'nmslib',
#       'space_type': 'cosinesimil',
#       'name': 'hnsw',
#       'parameters': {}}},
#     'title': {'type': 'text'}}},
#   'settings': {'index': {'number_of_shards': '2',
#     'provided_name': 'movie_7',
#     'knn': 'true',
#     'creation_date': '1725382799304',
#     'analysis': {'analyzer': {'default': {'type': 'standard',
#        'stopwords': '_english_'}}},
#     'number_of_replicas': '0',
#     'uuid': 'NYvUuJEBC5CQXlDxL56G',
#     'version': {'created': '136327827'}}}}}

# %%
vs_aos_client.indices.get(index="movie_sentence_7")
# Out:
# {'movie_sentence_7': {'aliases': {},
#   'mappings': {'properties': {'gnn_embedding': {'type': 'knn_vector',
#      'dimension': 64,
#      'method': {'engine': 'nmslib',
#       'space_type': 'cosinesimil',
#       'name': 'hnsw',
#       'parameters': {}}},
#     'id': {'type': 'text'},
#     'sentence_embedding': {'type': 'knn_vector',
#      'dimension': 384,
#      'method': {'engine': 'nmslib',
#       'space_type': 'cosinesimil',
#       'name': 'hnsw',
#       'parameters': {}}},
#     'title': {'type': 'text'}}},
#   'settings': {'index': {'number_of_shards': '2',
#     'provided_name': 'movie_sentence_7',
#     'knn': 'true',
#     'creation_date': '1725382799659',
#     'analysis': {'analyzer': {'default': {'type': 'standard',
#        'stopwords': '_english_'}}},
#     'number_of_replicas': '0',
#     'uuid': 'wSfUuJEByQpUVyt3MPDn',
#     'version': {'created': '136327827'}}}}}

# %%
vs_aos_client.indices.get(index="movie_gnn_7")
# Out:
# {'movie_gnn_7': {'aliases': {},
#   'mappings': {'properties': {'gnn_embedding': {'type': 'knn_vector',
#      'dimension': 64,
#      'method': {'engine': 'nmslib',
#       'space_type': 'cosinesimil',
#       'name': 'hnsw',
#       'parameters': {}}},
#     'id': {'type': 'text'},
#     'sentence_embedding': {'type': 'knn_vector',
#      'dimension': 384,
#      'method': {'engine': 'nmslib',
#       'space_type': 'cosinesimil',
#       'name': 'hnsw',
#       'parameters': {}}},
#     'title': {'type': 'text'}}},
#   'settings': {'index': {'number_of_shards': '2',
#     'provided_name': 'movie_gnn_7',
#     'knn': 'true',
#     'creation_date': '1725382799958',
#     'analysis': {'analyzer': {'default': {'type': 'standard',
#        'stopwords': '_english_'}}},
#     'number_of_replicas': '0',
#     'uuid': 'N4vUuJEBC5CQXlDxMp5L',
#     'version': {'created': '136327827'}}}}}

# %%
import json
from opensearchpy.helpers import bulk

def add_bulk_to_index(index_name, chunk):

    requests = []
    for rec in chunk:
        request = {
            "_op_type": "index",
            "_index": index_name,
            "title": (rec['fields'])['title'],
            #"year": (rec['fields'])['year'],
            #"averageRating": (rec['fields'])['averageRating'],
            #"numVotes": (rec['fields'])['numVotes'],
            #"runtime": (rec['fields'])['runtime'],
            "sentence_embedding": (rec['fields'])['sentence_embedding'],
            "gnn_embedding": (rec['fields'])['gnn_embedding']
        }
        request["id"] = rec['id']
        #print(request)
        requests.append(request)
    #print("\nBulk Load to Index")
    #print(len(requests))
    #print(requests)
    bulk(vs_aos_client, requests, max_chunk_bytes=(100 * 1024 * 1024))

# %%
import pandas as pd

counter=0;
CHUNK_SIZE=300
movie_reader = pd.read_csv('xmovie.csv', iterator=True)
sentence_reader = pd.read_csv('xsentence_embeddings.csv', iterator=True)
gnn_reader = pd.read_csv('xgnn_embeddings.csv', iterator=True)

MOVIE_MAP = {
    'title:string': 'title',
    'year:int': 'year',
    'averageRating:float': 'averageRating',
    'numVotes:int': 'numVotes',
    'runtime:int': 'runtime'
}

def process_next_chunk():
    aos_chunks = []
    movie_df = None
    sentence_df = None
    gnn_df = None
    try:
        movie_df = movie_reader.get_chunk(CHUNK_SIZE)
        sentence_df = sentence_reader.get_chunk(CHUNK_SIZE)
        gnn_df = gnn_reader.get_chunk(CHUNK_SIZE)
        if len(movie_df) == 0:
            return False
    except StopIteration as e: 
        print("Stop")
        print(e)
        return False

    start_index = -1
    for index, row in movie_df.iterrows():
        if start_index == -1:
            start_index = index
            #print(start_index)
        aos_rec = {"id": row["~id"], 'fields': {}}
        aos_chunks.append(aos_rec)
        try:
            for m in MOVIE_MAP:
                if pd.isna(row[m]):
                    #skip
                    pass
                else:
                    aos_rec['fields'][MOVIE_MAP[m]]=row[m]
        except Exception as e:
            print(f"Error on movie on {index} {row}")
            print("Exception: {}".format(type(e).__name__))
            print("Exception message: {}".format(e))
    for index, row in sentence_df.iterrows():
        try:
            aos_rec = aos_chunks[index-start_index]
            if row['~id']==aos_rec['id'] and 'embedding:vector' in row and len(row['embedding:vector']) > 0:
                aos_rec['fields']['sentence_embedding']=parse_str_embedding(row['embedding:vector'])
            else:
                raise Exception(f"Sentence Embedding/movie mismatch {str(index)} {str(row)} {str(aos_rec)}")
            #print(aos_rec['id'])
        except Exception as e:
            print(f"Error on {index} {row}")
            print("Exception: {}".format(type(e).__name__))
            print("Exception message: {}".format(e))
    for index, row in gnn_df.iterrows():
        try:
            aos_rec = aos_chunks[index-start_index]
            if row['~id']==aos_rec['id'] and 'embedding:vector' in row and len(row['embedding:vector']) > 0:
                aos_rec['fields']['gnn_embedding']=parse_str_embedding(row['embedding:vector'])
            else:
                raise Exception(f"GNN Embedding/movie mismatch {str(index)} {str(row)} {str(aos_rec)}")
        except Exception as e:
            print(f"Error on {index} {row}")
            print("Exception: {}".format(type(e).__name__))
            print("Exception message: {}".format(e))

    print(len(aos_chunks))
    print(aos_chunks[0]['id'])
    add_bulk_to_index('movie_7', aos_chunks)
    add_bulk_to_index('movie_sentence_7', aos_chunks)
    add_bulk_to_index('movie_gnn_7', aos_chunks)
    return True


while True:
    ret = process_next_chunk()
    counter=counter+CHUNK_SIZE
    print(counter)
    #print(ret)
   
    if not ret:
        break

#ret = process_next_chunk()
print("\nDone")
# Out:
# 300
# tt0000009
# 300
# 300
# tt0003289
# 600
# 300
# tt0004272
# 900
# 300
# tt0005032
# 1200
# 300
# tt0005648
# 1500
# 300
# tt0006231
# 1800
# 300
# tt0006748
# 2100
# 300
# tt0007233
# 2400
# 300
# tt0007692
# 2700
# 300
# tt0008144
# 3000
# 300
# tt0008543
# 3300
# 300
# tt0008956
# 3600
# 300
# tt0009345
# 3900
# 300
# tt0009728
# 4200
# 300
# tt0010130
# 4500
# 300
# tt0010519
# 4800
# 300
# tt0010920
# 5100
# 300
# tt0011302
# 5400
# 300
# tt0011677
# 5700
# 300
# tt0012039
# 6000
# 300
# tt0012408
# 6300
# 300
# tt0012757
# 6600
# 300
# tt0013120
# 6900
# 300
# tt0013481
# 7200
# 300
# tt0013837
# 7500
# 300
# tt0014205
# 7800
# 300
# tt0014565
# 8100
# 300
# tt0014924
# 8400
# 300
# tt0015263
# 8700
# 300
# tt0015629
# 9000
# 300
# tt0016005
# 9300
# 300
# tt0016358
# 9600
# 300
# tt0016723
# 9900
# 300
# tt0017095
# 10200
# 300
# tt0017452
# 10500
# 300
# tt0017822
# 10800
# 300
# tt0018179
# 11100
# 300
# tt0018530
# 11400
# 300
# tt0018869
# 11700
# 300
# tt0019225
# 12000
# 300
# tt0019584
# 12300
# 300
# tt0019966
# 12600
# 300
# tt0020337
# 12900
# 300
# tt0020712
# 13200
# 300
# tt0021111
# 13500
# 300
# tt0021504
# 13800
# 300
# tt0021916
# 14100
# 300
# tt0022309
# 14400
# 300
# tt0022700
# 14700
# 300
# tt0023121
# 15000
# 300
# tt0023525
# 15300
# 300
# tt0023937
# 15600
# 300
# tt0024300
# 15900
# 300
# tt0024692
# 16200
# 300
# tt0025087
# 16500
# 300
# tt0025463
# 16800
# 300
# tt0025857
# 17100
# 300
# tt0026248
# 17400
# 300
# tt0026621
# 17700
# 300
# tt0027018
# 18000
# 300
# tt0027406
# 18300
# 300
# tt0027761
# 18600
# 300
# tt0028144
# 18900
# 300
# tt0028498
# 19200
# 300
# tt0028873
# 19500
# 300
# tt0029250
# 19800
# 300
# tt0029655
# 20100
# 300
# tt0030039
# 20400
# 300
# tt0030413
# 20700
# 300
# tt0030803
# 21000
# 300
# tt0031178
# 136200
# 300
# tt0238465
# 136500
# 300
# tt0239405
# 136800
# 300
# tt0240017
# 137100
# 300
# tt0240786
# 137400
# 300
# tt0241505
# 137700
# 300
# tt0241965
# 138000
# 300
# tt0242568
# 138300
# 300
# tt0243214
# 138600
# 300
# tt0243972
# 138900
# 300
# tt0244570
# 139200
# 300
# tt0245281
# 139500
# 300
# tt0246072
# 139800
# 300
# tt0246729
# 140100
# 300
# tt0247455
# 140400
# 300
# tt0248139
# 140700
# 300
# tt0249039
# 141000
# 300
# tt0249778
# 141300
# 300
# tt0250451
# 141600
# 300
# tt0251068
# 141900
# 300
# tt0251701
# 142200
# 300
# tt0252261
# 142500
# 300
# tt0252878
# 142800
# 300
# tt0253538
# 143100
# 300
# tt0254148
# 143400
# 300
# tt0254718
# 143700
# 300
# tt0255300
# 144000
# 300
# tt0255885
# 144300
# 300
# tt0256374
# 144600
# 300
# tt0257151
# 144900
# 300
# tt0257807
# 145200
# 300
# tt0258328
# 145500
# 300
# tt0258867
# 145800
# 300
# tt0259431
# 146100
# 300
# tt0260037
# 146400
# 300
# tt0260727
# 146700
# 300
# tt0261277
# ---------------------------------------------------------------------------
# BulkIndexError                            Traceback (most recent call last)
# Cell In[101], line 84
#      80     return True
#      83 while True:
# ---> 84     ret = process_next_chunk()
#      85     counter=counter+CHUNK_SIZE
#      86     print(counter)
#
# Cell In[101], line 77, in process_next_chunk()
#      75 print(len(aos_chunks))
#      76 print(aos_chunks[0]['id'])
# ---> 77 add_bulk_to_index('movie_7', aos_chunks)
#      78 add_bulk_to_index('movie_sentence_7', aos_chunks)
#      79 add_bulk_to_index('movie_gnn_7', aos_chunks)
#
# Cell In[67], line 25, in add_bulk_to_index(index_name, chunk)
#      21     requests.append(request)
#      22 #print("\nBulk Load to Index")
#      23 #print(len(requests))
#      24 #print(requests)
# ---> 25 bulk(vs_aos_client, requests, max_chunk_bytes=(100 * 1024 * 1024))
#
# File ~/anaconda3/envs/JupyterSystemEnv/lib/python3.10/site-packages/opensearchpy/helpers/actions.py:423, in bulk(client, actions, stats_only, ignore_status, *args, **kwargs)
#     421 # make streaming_bulk yield successful results so we can count them
#     422 kwargs["yield_ok"] = True
# --> 423 for ok, item in streaming_bulk(client, actions, ignore_status=ignore_status, *args, **kwargs):  # type: ignore
#     424     # go through request-response pairs and detect failures
#     425     if not ok:
#     426         if not stats_only:
#
# File ~/anaconda3/envs/JupyterSystemEnv/lib/python3.10/site-packages/opensearchpy/helpers/actions.py:336, in streaming_bulk(client, actions, chunk_size, max_chunk_bytes, raise_on_error, expand_action_callback, raise_on_exception, max_retries, initial_backoff, max_backoff, yield_ok, ignore_status, *args, **kwargs)
#     333     time.sleep(min(max_backoff, initial_backoff * 2 ** (attempt - 1)))
#     335 try:
# --> 336     for data, (ok, info) in zip(
#     337         bulk_data,
#     338         _process_bulk_chunk(
#     339             client,
#     340             bulk_actions,
#     341             bulk_data,
#     342             raise_on_exception,
#     343             raise_on_error,
#     344             ignore_status,
#     345             *args,
#     346             **kwargs,
#     347         ),
#     348     ):
#     349         if not ok:
#     350             action, info = info.popitem()
#
# File ~/anaconda3/envs/JupyterSystemEnv/lib/python3.10/site-packages/opensearchpy/helpers/actions.py:272, in _process_bulk_chunk(client, bulk_actions, bulk_data, raise_on_exception, raise_on_error, ignore_status, *args, **kwargs)
#     265 else:
#     266     gen = _process_bulk_chunk_success(
#     267         resp=resp,
#     268         bulk_data=bulk_data,
#     269         ignore_status=ignore_status,
#     270         raise_on_error=raise_on_error,
#     271     )
# --> 272 yield from gen
#
# File ~/anaconda3/envs/JupyterSystemEnv/lib/python3.10/site-packages/opensearchpy/helpers/actions.py:201, in _process_bulk_chunk_success(resp, bulk_data, ignore_status, raise_on_error)
#     198         yield ok, {op_type: item}
#     200 if errors:
# --> 201     raise BulkIndexError(f"{len(errors)} document(s) failed to index.", errors)
#
# BulkIndexError: ('158 document(s) failed to index.', [{'index': {'_index': 'movie_7', '_id': '1%3A0%3ABknjuJEBSE2l0lVlf1Kj', 'status': 429, 'error': {'type': 'circuit_breaking_exception', 'reason': 'rejected execution of primary operation [throttled]', 'bytes_wanted': 0, 'bytes_limit': 0, 'durability': 'TRANSIENT'}, 'data': {'title': 'The Sea That Thinks', 'sentence_embedding': [-0.0073682214, 0.019250656, -0.010090124, -0.024919767, -0.020966476, -0.019668018, 0.13269822, 0.00840397, 0.08124151, -0.0036701015, -0.01711618, -0.09719962, -0.0275231, 0.0055159354, 7.6171105e-05, -0.004491222, -0.04325222, -0.048007246, 0.005758448, -0.045097988, -0.022081219, 0.08799281, -0.034015797, -0.025320169, -0.11593973, 0.060657006, 0.054371003, -0.00234633, -0.00016415463, -0.026445173, -0.03153531, 0.04825409, -0.00950621, 0.0082877, 0.027547047, 0.07667674, -0.061159644, 0.0065331534, -0.020283407, 0.02357655, -0.07426895, -0.03161429, 0.05085863, 0.08307199, -0.042697262, -0.04106764, 0.08044873, -0.009300964, 0.01273645, 0.031741135, -0.07184918, -0.036541115, -0.04650799, -0.015638484, -0.009509169, -0.024703713, -0.032556098, 0.0026170618, 0.04158153, -0.014628658, 0.04935975, 0.031561356, -0.0024283936, -0.012188763, 0.08615023, 0.014757288, -0.01924762, 0.09917946, -0.104899414, -0.024394732, 0.05222386, 0.02186686, -0.009753615, -0.0035143178, -0.010060655, -0.07013273, -0.012411329, -0.03879678, 0.045810517, -0.024858152, -0.018880496, -0.035855986, -0.08760498, 0.038282406, 0.05266375, -0.033141922, 0.033905715, -0.02458641, -0.035343457, 0.03633149, -0.07506045, -0.14055301, -0.04516885, 0.008859539, 0.003896218, 0.10848888, -0.07595863, 0.019041963, 0.017024036, 0.07544149, 0.03842532, 0.052578032, -0.031587385, -0.003574201, 0.05327308, -0.06371331, 0.02357484, 0.041443255, 0.007559354, -0.028277682, -0.1023375, -0.04890969, -0.04365177, 0.053312395, 0.007138016, 0.04263147, 0.017546728, -0.022594817, -0.03609881, -0.059320927, -0.013948458, 0.045633294, 0.038568597, 0.08606632, -0.030376818, 0.012530451, 0.006204841, -5.725822e-33, 0.023197172, -0.031103417, 0.0763566, -0.03980469, 0.029143643, 0.012084728, -0.010567419, 0.000732102, -0.041845728, 0.0036474927, -0.11593761, 0.036063403, -0.091387905, 0.027038315, 0.052129317, -0.005247202, -0.08173982, -0.045226317, -0.108435206, -0.049311135, 0.03204879, 0.141036, 0.024443781, -0.09101311, -0.038212597, -0.038111936, 0.028979667, -0.035033356, -0.01237115, 0.0765105, -0.034322545, 0.052104626, -0.040836226, 0.030011186, 0.0039133895, -0.04290762, -0.007088455, 0.009481232, -0.024018435, 0.002618869, -0.0053081275, 0.024095505, -0.037649464, 0.035382744, 0.067267776, -0.011986951, 0.057748575, 0.039543305, 0.013899778, 0.025137678, 0.048331965, -0.039633367, 0.028870318, -0.002843966, -0.019142957, -0.0023448768, 0.074189655, 0.061852522, -0.0164544, 0.019825362, -0.0030684085, -0.0239962, 0.083227105, 0.013434893, 0.1033974, 0.10926239, -0.0049702697, -0.05874066, -0.037957396, -0.032079183, -0.047767047, 0.031338695, 0.06366414, 0.046861354, -0.086964786, 0.014819165, 0.03799683, 0.0012155302, -0.068338215, -0.051581286, 0.010764815, -0.00012119822, -0.061032187, 0.083053626, 0.0001461415, 0.07360462, -0.01002586, -0.0021518928, 0.05911306, -0.02915542, -0.114987954, -0.024411464, 0.124044284, -0.13878521, -0.12543163, 3.6108608e-33, -0.04325128, -0.067926355, -0.0025468725, 0.024019916, 0.026710508, -0.057946388, 0.044612303, 0.037585072, -0.044578265, 0.050601494, -0.06602709, -0.095451176, 0.11142549, 0.02879427, 0.04489378, -0.068926364, 0.060489513, 0.03860654, 0.029599467, -0.0071424856, -0.016647475, -0.083479784, 0.01502262, 0.07641278, -0.015970971, 0.079288885, 0.053383823, -0.0414112, -0.0842239, -0.06539126, -0.059835903, 0.05351999, 0.0021060174, -0.049097512, -0.0821793, 0.04545621, -0.018797835, 0.031576753, -0.018434245, -0.009958265, -0.022133438, -0.07193422, -0.031785443, 0.0287883, -0.08532441, 0.053658783, 0.06766678, 0.12308637, 0.011187614, -0.006 ...

# %%
def get_field(h, fname):
    if fname in h['_source']:
        return h['_source'][fname]
    else:
        return ""

# %%
search_text="poseidon"
query = {
    "size": 30,
    "query": {
        "multi_match": {
                "query": search_text,
                'fields': ['title^2']
        }
    }
}
lex_result = vs_aos_client.search(index="movie_sentence_6", body=query)
print(f"Lexical results: {search_text}")
print("id|score|title")
for idx, h in enumerate(lex_result["hits"]["hits"]):
    print(f"{h['_id']}|{h['_score']}|{get_field(h, 'title')}")
# Out:
# Lexical results: poseidon
# id|score|title
# 1%3A0%3A-eG2uJEBKwGr2Tq_jzp6|27.542017|Poseidon
# 1%3A0%3A5N6wuJEBKwGr2Tq_Bq9w|23.440931|The Poseidon Explosion
# 1%3A0%3AZd2uuJEBKwGr2Tq_DemX|23.440931|The Poseidon Adventure
# 1%3A0%3ADEKuuJEBSE2l0lVlZE05|19.312716|Beyond the Poseidon Adventure
# 1%3A0%3AM9-zuJEBKwGr2Tq_Kuxa|16.802502|'Poseidon' speshit na pomoshch

# %%
search_text="Poseidon"
search_vector=get_embeddings(search_text).tolist()

query={
    "size": 30,
    "query": {
        "knn": {
            "sentence_embedding":{
                "vector":search_vector,
                "k":50
            }
        }
    }
}

sem_result = vs_aos_client.search(index="movie_sentence_6",  body=query)
print(f"Semantic/sentence embedding results: {search_text}")
print("id|score|title")
for idx, h in enumerate(sem_result["hits"]["hits"]):
    print(f"{h['_id']}|{h['_score']}|{get_field(h, 'title')}")
# Out:
# Semantic/sentence embedding results: Poseidon
# id|score|title
# 1%3A0%3A-eG2uJEBKwGr2Tq_jzp6|1.0|Poseidon
# 1%3A0%3AZd2uuJEBKwGr2Tq_DemX|0.87066627|The Poseidon Adventure
# 1%3A0%3ADEKuuJEBSE2l0lVlZE05|0.8031267|Beyond the Poseidon Adventure
# 1%3A0%3A5N6wuJEBKwGr2Tq_Bq9w|0.7876582|The Poseidon Explosion
# 1%3A0%3AM9-zuJEBKwGr2Tq_Kuxa|0.7825502|'Poseidon' speshit na pomoshch
# 1%3A0%3Aft-zuJEBKwGr2Tq_OvJt|0.7357252|Professor Cupidon
# 1%3A0%3AQd6vuJEBKwGr2Tq_gXyy|0.72898924|Pardon Cupidon
# 1%3A0%3AFkKvuJEBSE2l0lVlvtOx|0.6856981|Captain Conan
# 1%3A0%3AZOC0uJEBKwGr2Tq_w4tf|0.6788629|Poseshchenie
# 1%3A0%3ABt2tuJEBKwGr2Tq__-Nu|0.67712104|The Omega Man
# 1%3A0%3Ald2tuJEBKwGr2Tq_K5Yl|0.67591774|Dino
# 1%3A0%3Ant2suJEBKwGr2Tq_1XQN|0.674882|Tyrant of the Sea
# 1%3A0%3Ax92ruJEBKwGr2Tq_vhBE|0.67476076|The Sea God
# 1%3A0%3AXUGtuJEBSE2l0lVlSeOY|0.673191|Captain Fracasse
# 1%3A0%3A1tyruJEBKwGr2Tq_ItX-|0.67319095|Captain Fracasse
# 1%3A0%3AE0GsuJEBSE2l0lVlUotp|0.67319095|Captain Fracasse
# 1%3A0%3AR0GruJEBSE2l0lVlsUp1|0.6718071|Scarlet Seas
# 1%3A0%3AfkKvuJEBSE2l0lVlg7zB|0.6717847|Warlock: The Armageddon
# 1%3A0%3AX0KvuJEBSE2l0lVlzdi9|0.6715723|Omega Doom
# 1%3A0%3AJuCzuJEBKwGr2Tq_3TM1|0.67152774|The Sailor
# 1%3A0%3AhtyruJEBKwGr2Tq_hfgl|0.6711331|Percy
# 1%3A0%3AKd2tuJEBKwGr2Tq__-Nv|0.6711331|Percy
# 1%3A0%3AE0SzuJEBSE2l0lVlDyH7|0.6711331|Percy
# 1%3A0%3ACkOwuJEBSE2l0lVl2UK7|0.668759|Sangathan
# 1%3A0%3A5d6wuJEBKwGr2Tq_JruJ|0.6685299|Hades
# 1%3A0%3At96vuJEBKwGr2Tq_ro0B|0.6685299|Hades
# 1%3A0%3Ax92tuJEBKwGr2Tq_K5Yl|0.66842955|Hercules
# 1%3A0%3A4kKuuJEBSE2l0lVlrWiP|0.66842955|Hercules
# 1%3A0%3AkEKvuJEBSE2l0lVl3N6_|0.66842955|Hercules
# 1%3A0%3Awt-xuJEBKwGr2Tq_ZTaD|0.66842955|Hercules
